# %% [markdown]
# # Explore here

# %%
import pandas as pd

df= pd.read_csv('/workspaces/proyecto_enc/data/raw/df_seleccionado_bruto.csv')
df
# Out:
#         Unnamed: 0  id_vivienda      folio  id_persona  region  area  nse  p9  \
# 0                0      1000901  100090101           1      16     2    4   3
# 1                1      1000901  100090101           2      16     2    4   3
# 2                2      1000901  100090101           3      16     2    4   3
# 3                3      1000902  100090201           1      16     2    4   4
# 4                4      1000902  100090201           2      16     2    4   4
# ...            ...          ...        ...         ...     ...   ...  ...  ..
# 202226      202226      4585804  458580401           2       9     1    3   3
# 202227      202227      4585804  458580401           3       9     1    3   3
# 202228      202228      4585807  458580701           1       9     1    3   3
# 202229      202229      4585807  458580701           2       9     1    3   3
# 202230      202230      4585807  458580701           3       9     1    3   3
#
# ...
